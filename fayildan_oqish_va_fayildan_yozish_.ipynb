# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/fayllar-va-malumotlar-ombor/blob/main/fayildan_oqish_va_fayildan_yozish_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# pandas kutubxonasi faillar bilan ishlidigan bir nechta funksialardan iborat
#
# 1 - read_csv ) vergul bilan ajratilgan jadval faillarni o'qish uchun
#
# 2 - read_table ) probel bo'sh katak bn ajratilgan jadval faillarni oqish uchun
#
# 3 - read_excel ) xls aksinch xlsx formatidagi Excel faillarni o'qish uchun
#
# 4 - read_clipboard ) ko'chirilgan xotiradagi jadvalni o'qish
#
# 5 - read_hdf ) HDF5 formatidagi fillarni o'qish
#
# 6 - read_html  ) HTML web sahifadagi barcha jadvallarni o'qish
#
# 7 - read_json ) JSON malumotlarni o'qish
#
# 8 - read_pickle ) pickle formatidagi faillarni oqish
#
# 9 - read_sql ) SQL queri dan qaitgan malumotlarni oqish

# %%
# !wget https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# !wget orqali githubdan anvarnarz praktikum faillaridan 'mers csv' failini kirgizdik kirgizdik
# Out:
# --2026-01-31 17:10:10--  https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/refs/heads/main/merc.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 728047 (711K) [text/plain]
# Saving to: ‘merc.csv.2’
#
# merc.csv.2          100%[===================>] 710.98K  --.-KB/s    in 0.04s
#
# 2026-01-31 17:10:10 (15.9 MB/s) - ‘merc.csv.2’ saved [728047/728047]

# %%
# !git clone https://github.com/anvarnarz/praktikum_datasets
# !git clone funksiasi orqali  anvar narz praktikum datasets ini hamma failini google coolabga kochirib oldik
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv('merc.csv')
df.head() # mers.csv failini google kolabga download qilib oldik
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df2 = pd.read_csv("sample_data/california_housing_test.csv")
df2.head() # sample_data failining ichidan california_housing_test.csv failini google colabga download qilib oldik
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
error = pd.read_excel("praktikum_datasets/uzbekistan.xlsx", index_col=0)
error
# excel yordamida prakikum_daqtasets ichidan uzbekistan.xlsx failini download qilib oldik
# va ung index sifatida 0 - qatordagi bolinishi nomli ustunni qoib oldik
# Out:
#                                Maydoni (kv.km)  Aholisi
# Boʻlinishi
# Andijon viloyati                          4200  1899000
# Buxoro viloyati                          39400  1384700
# Fargʻona viloyati                         6800  2597000
# Jizzax viloyati                          20500   910500
# Xorazm viloyati                           6300  1200000
# Namangan viloyati                         7900  1862000
# Navoiy viloyati                         110800   767500
# Qashqadaryo viloyati                     28400  2029000
# Qoraqalpogʻiston Respublikasi           160000  1200000
# Samarqand viloyati                       16400  2322000
# Sirdaryo viloyati                         5100   648100
# Surxondaryo viloyati                     20800  1676000
# Toshkent viloyati                        15300  4450000

# %%
error = pd.read_excel("praktikum_datasets/uzbekistan.xlsx", index_col=0 , names = ['hudud', 'kvv*', 'xalq'])
error
# index ni 0 - ustunni orniga qodik va names = funksiasi orqali  ustunning nomlarini ozagartirib oldik
# Out:
#                                  kvv*     xalq
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv('praktikum_datasets/automobile_data.csv', index_col='index', nrows=15)
# (automobile_data.csv) failini download qilib oldik va 2 ta index bolganligi uchun bitta indexni
# index_col='index qilib bittasini qoldirdik va nrows = 15 funksiasi orqali tepadan 15 ta qatorni chiqarib oldik
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
saqlash = pd.read_excel("praktikum_datasets/uzbekistan.xlsx", index_col=0)
saqlash
# Out:
#                                Maydoni (kv.km)  Aholisi
# Boʻlinishi
# Andijon viloyati                          4200  1899000
# Buxoro viloyati                          39400  1384700
# Fargʻona viloyati                         6800  2597000
# Jizzax viloyati                          20500   910500
# Xorazm viloyati                           6300  1200000
# Namangan viloyati                         7900  1862000
# Navoiy viloyati                         110800   767500
# Qashqadaryo viloyati                     28400  2029000
# Qoraqalpogʻiston Respublikasi           160000  1200000
# Samarqand viloyati                       16400  2322000
# Sirdaryo viloyati                         5100   648100
# Surxondaryo viloyati                     20800  1676000
# Toshkent viloyati                        15300  4450000

# %%
saqlash.to_csv('newuzb.csv')
#saqlash dataframeni newuzb.csv failini ochib unga saqlab oldik

# %%
obj = saqlash.Aholisi
obj # saqlash datafremidan Aholisi qimatini olib uni seriesga ozgartirib oldik
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %%
obj.to_csv('uzbaholisi.csv')
# obj ozgaruvchini to_csv orqali uzbaholisi failiga download qilib oldik 'Aholisi' qimatni series qilib olgandik

# %% [markdown]
# failni Series korinishida chaqirish

# %%
data = pd.read_csv('uzbaholisi.csv', index_col=0)
series = data.squeeze()
print(series)
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %% [markdown]
# boshqa failni saqlab olamiz

# %%
avto = pd.read_csv('praktikum_datasets/automobile_data.csv', index_col='index', nrows=15)
# avtomobile_data.csv ni chaqirib oldik va unga ishlov berdik

# %%
avto.to_excel('avto.xlsx', index=False, columns=['company', 'body-style', 'length'])
# avto dataframeni excel korinishida (avto.xlsx) nomi bn saqlab oldik va index=False orqali indexni ocbirish orqali va
# ozmizga kerakli bolgan qimatlani salqashni buyurdik

# %%
pd.read_excel('avto.xlsx', index_col=0)
# saqlb olgan failimizni chaqirib oldik va huddi saqlab lganimizdek 15 ta qator va biz hoxlagan 3 ta qimatni chiqarib berdi
# Out:
#               body-style  length
# company
# alfa-romero  convertible   168.8
# alfa-romero  convertible   168.8
# alfa-romero    hatchback   171.2
# audi               sedan   176.6
# audi               sedan   176.6
# audi               sedan   177.3
# audi               wagon   192.7
# bmw                sedan   176.8
# bmw                sedan   176.8
# bmw                sedan   176.8
# bmw                sedan   189.0
# bmw                sedan   193.8
# bmw                sedan   197.0
# chevrolet      hatchback   141.1
# chevrolet      hatchback   155.9

# %% [markdown]
# Boshqa fail chaqirib va saqlimiz

# %%
cars = pd.read_csv('praktikum_datasets/breast-cancer.csv', index_col='id', nrows=10)
cars
# praktikum dataset failidan breast cancer failini download qilib oldik va index raqamini ornida id ni qoib qodik
# nrows orqali 1 qatorni ham chiqarib oldik
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
# 843786           M        12.45         15.70           82.57      477.1
# 844359           M        18.25         19.98          119.60     1040.0
# 84458202         M        13.71         20.83           90.20      577.9
# 844981           M        13.00         21.82           87.50      519.8
# 84501001         M        12.46         24.04           83.97      475.9
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760         0.30010
# ...

# %%
cars.to_excel('drive/MyDrive/loiha.xlsx', index=False,  columns=['diagnosis', 'radius_mean', 'texture_mean'])
# dataframega loiha.xlsx deb nom berib oldik saqlab olishda index=False orqali indexmi ochirib saqlashni buirdik
# va columns orqali ozimizga kerakli bolgan qimatlatni saqlab olvik
# malumot uchun saqlashda drive failini ichidagi MyDrive ga loiha.xlsx deb nom berib saqlab oldik

# %%
pd.read_excel('drive/MyDrive/loiha.xlsx', index_col=0)
#  saqlab olgan loiha.xlsx ni pd.read_excel qilib chaqirib olvik va index_col=0 orqali 0 chi ustunni  index ni orniga qoib oldik
# Out:
#            radius_mean  texture_mean
# diagnosis
# M                17.99         10.38
# M                20.57         17.77
# M                19.69         21.25
# M                11.42         20.38
# M                20.29         14.34
# M                12.45         15.70
# M                18.25         19.98
# M                13.71         20.83
# M                13.00         21.82
# M                12.46         24.04
