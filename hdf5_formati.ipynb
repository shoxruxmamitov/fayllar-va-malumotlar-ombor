# %% [markdown]
# <a href="https://colab.research.google.com/github/shoxruxmamitov/fayllar-va-malumotlar-ombor/blob/main/hdf5_formati.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# fayildan oqish

# %%
! wget https://github.com/anvarnarz/praktikum_datasets/blob/main/merc.csv
# Out:
# --2026-02-06 10:18:42--  https://github.com/anvarnarz/praktikum_datasets/blob/main/merc.csv
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘merc.csv.1’
#
# merc.csv.1              [ <=>                ] 922.75K  --.-KB/s    in 0.01s
#
# 2026-02-06 10:18:43 (75.5 MB/s) - ‘merc.csv.1’ saved [944900]

# %%
! git clone https://github.com/anvarnarz/praktikum_datasets
# Out:
# fatal: destination path 'praktikum_datasets' already exists and is not an empty directory.

# %%
df = pd.read_csv('praktikum_datasets/merc.csv')
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
pd.read_excel("praktikum_datasets/uzbekistan.xlsx", index_col=0, names = ['hudud', 'kvv*', 'aholi'])
# Out:
#                                  kvv*    aholi
# hudud
# Andijon viloyati                 4200  1899000
# Buxoro viloyati                 39400  1384700
# Fargʻona viloyati                6800  2597000
# Jizzax viloyati                 20500   910500
# Xorazm viloyati                  6300  1200000
# Namangan viloyati                7900  1862000
# Navoiy viloyati                110800   767500
# Qashqadaryo viloyati            28400  2029000
# Qoraqalpogʻiston Respublikasi  160000  1200000
# Samarqand viloyati              16400  2322000
# Sirdaryo viloyati                5100   648100
# Surxondaryo viloyati            20800  1676000
# Toshkent viloyati               15300  4450000

# %%
pd.read_csv('praktikum_datasets/automobile_data.csv', index_col='index', nrows=15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %% [markdown]
# fayilga yozish

# %%
uzaholi = pd.read_excel("praktikum_datasets/uzbekistan.xlsx", index_col=0) # names = ['hudud', 'kvv*', 'aholi'])
uzaholi
# Out:
#                                Maydoni (kv.km)  Aholisi
# Boʻlinishi
# Andijon viloyati                          4200  1899000
# Buxoro viloyati                          39400  1384700
# Fargʻona viloyati                         6800  2597000
# Jizzax viloyati                          20500   910500
# Xorazm viloyati                           6300  1200000
# Namangan viloyati                         7900  1862000
# Navoiy viloyati                         110800   767500
# Qashqadaryo viloyati                     28400  2029000
# Qoraqalpogʻiston Respublikasi           160000  1200000
# Samarqand viloyati                       16400  2322000
# Sirdaryo viloyati                         5100   648100
# Surxondaryo viloyati                     20800  1676000
# Toshkent viloyati                        15300  4450000

# %%
uzaholi.to_csv('uz_aholi.csv')

# %%
obj = uzaholi.Aholisi
obj
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %%
obj.to_csv('uz_aholisi.csv')

# %%
ter = pd.read_csv('uz_aholisi.csv', index_col=0)
ret_squezze= ter.squeeze()
ret_squezze
# Out:
# Boʻlinishi
# Andijon viloyati                 1899000
# Buxoro viloyati                  1384700
# Fargʻona viloyati                2597000
# Jizzax viloyati                   910500
# Xorazm viloyati                  1200000
# Namangan viloyati                1862000
# Navoiy viloyati                   767500
# Qashqadaryo viloyati             2029000
# Qoraqalpogʻiston Respublikasi    1200000
# Samarqand viloyati               2322000
# Sirdaryo viloyati                 648100
# Surxondaryo viloyati             1676000
# Toshkent viloyati                4450000
# Name: Aholisi, dtype: int64

# %%
df2 = pd.read_csv('praktikum_datasets/automobile_data.csv', index_col='index', nrows=15)
df2
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
df2.to_excel('drive/MyDrive/new_automobile.xlsx', index=False, columns = ['company', 'body-style', 'price'])

# %%
saaq = pd.read_excel('drive/MyDrive/new_automobile.xlsx')
saaq
# Out:
#         company   body-style  price
# 0   alfa-romero  convertible  13495
# 1   alfa-romero  convertible  16500
# 2   alfa-romero    hatchback  16500
# 3          audi        sedan  13950
# 4          audi        sedan  17450
# 5          audi        sedan  15250
# 6          audi        wagon  18920
# 7           bmw        sedan  16430
# 8           bmw        sedan  16925
# 9           bmw        sedan  20970
# 10          bmw        sedan  30760
# 11          bmw        sedan  41315
# 12          bmw        sedan  36880
# 13    chevrolet    hatchback   5151
# 14    chevrolet    hatchback   6295

# %% [markdown]
# hdf5 formati

# %%
hdfobj= pd.HDFStore('data.h5')

# %%
df.head()
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0        SLK  2005   5200    Automatic    63000   Petrol  325  32.1
# 1    S Class  2017  34948    Automatic    27000   Hybrid   20  61.4
# 2   SL CLASS  2016  49948    Automatic     6200   Petrol  555  28.0
# 3    G Class  2016  61948    Automatic    16000   Petrol  325  30.4
# 4    G Class  2016  73948    Automatic     4000   Petrol  325  30.1
#
#    engineSize
# 0         1.8
# 1         2.1
# 2         5.5
# 3         4.0
# 4         4.0

# %%
df2.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage  price
# index
# 0                 four         111               21  13495
# 1                 four         111               21  16500
# 2                  six         154               19  16500
# 3                 four         102               24  13950
# 4                 five         115               18  17450

# %%
hdfobj.put('uzbekdata', df)

# %%
hdfobj.put('uzbekcars', df2)

# %%
hdfobj.keys()
# Out:
# ['/uzbekcars', '/uzbekdata']

# %%
hdfobj['uzbekcars'].tail(10)
# Out:
#          company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 5           audi      sedan        99.8   177.3         ohc             five
# 6           audi      wagon       105.8   192.7         ohc             five
# 9            bmw      sedan       101.2   176.8         ohc             four
# 10           bmw      sedan       101.2   176.8         ohc             four
# 11           bmw      sedan       101.2   176.8         ohc              six
# 13           bmw      sedan       103.5   189.0         ohc              six
# 14           bmw      sedan       103.5   193.8         ohc              six
# 15           bmw      sedan       110.0   197.0         ohc              six
# 16     chevrolet  hatchback        88.4   141.1           l            three
# 17     chevrolet  hatchback        94.5   155.9         ohc             four
#
#        horsepower  average-mileage  price
# index
# 5             110               19  15250
# ...
